# %%
import pandas as pd
import csv
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style = "whitegrid")

# %%
test_set = pd.read_csv("set_for_seaborn2.csv")

# %%
test_set["Date"] = pd.to_datetime(test_set["Date"], format = "%m/%d/%y")
test_set["New date"] = test_set["Date"].dt.strftime("%b %d")

# %%
test_set1 = test_set.copy()
test_set1 = test_set1.drop_duplicates(subset = "New date")

# %%
fig, ax = plt.subplots()
sns.lineplot(test_set.Date, test_set.Amount, hue = test_set.Type)
fig.set_figheight(10)
fig.set_figwidth(15)
ax.set_xticks(["1/5/20", "1/12/20", "1/19/20", "1/26/20", "2/2/20", "2/9/20", "2/16/20", "2/23/20", "3/1/20", "3/8/20"])
ax.set_xticklabels(test_set1["New date"][::7], rotation = 45, fontsize='18')
ax.set_xlabel('Dates',fontsize = '22')
ax.set_ylabel('Amount',fontsize = '22')
ax.set_yticklabels(['0','0','200000','400000','600000','800000','100000','120000'],fontsize='18')
#plt.yscale("log")
plt.title('Amount of Cumulative Media Posts and Deaths Over Time',fontsize='22', y=1.08)
plt.setp(ax.get_legend().get_texts(), fontsize='22')
plt.savefig('Mediaposts_deaths_time.png')
plt.show()
# Out:
# /home/degdal/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
