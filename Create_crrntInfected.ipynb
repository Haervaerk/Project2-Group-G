# %%
import pandas as pd
import csv
import numpy as np

# %%
df_deaths=pd.read_csv('deaths.tsv', sep='\t')
df_infect=pd.read_csv('infected.tsv', sep='\t')
df_revocer=pd.read_csv('recovered.tsv', sep='\t')

# %%
df_infect[df_infect.columns[4:]]
#df_deaths[df_deaths.columns[4:]]
#df_revocer[df_revocer.columns[4:]]
# Out:
#      1/22/2020  1/23/2020  1/24/2020  1/25/2020  1/26/2020  1/27/2020  \
# 0            2          3          5          7          8          8
# 1            2          1          2          2          4          4
# 2            0          1          3          3          4          5
# 3            0          0          0          1          1          1
# 4            0          0          0          3          4          4
# ..         ...        ...        ...        ...        ...        ...
# 437          0          0          0          0          0          0
# 438          0          0          0          0          0          0
# 439          0          0          0          0          0          0
# 440          0          0          0          0          0          0
# 441          0          0          0          0          0          0
#
#      1/28/2020  1/29/2020  1/30/2020  1/31/2020  ...  3/5/2020  3/6/2020  \
# 0           14         14         14         19  ...        47        48
# 1            7          7         11         15  ...       360       420
# 2            7          7         10         13  ...       117       130
# 3            1          1          1          1  ...         1         1
# 4            4          7          8          8  ...        50        83
# ..         ...        ...        ...        ...  ...       ...       ...
# 437          0          0          0          0  ...         0         0
# 438          0          0          0          0  ...         0         0
# 439          0          0          0          0  ...         0         0
# 440          0          0          0          0  ...         0         0
# 441          0          0          0          0  ...         0         0
#
#      3/7/2020  3/8/2020  3/9/2020  3/10/2020  3/11/2020  3/12/2020  3/13/2020  \
# 0          50        50        50         53         59         70         75
# 1         461       502       511        581        639        639        701
# 2         138       150       150        160        178        178        200
# 3           1         1         1          1          1          1          1
# 4          93        99       117        129        149        149        197
# ..        ...       ...       ...        ...        ...        ...        ...
# 437         0         0         0          0          0          0          0
# 438         0         0         0          0          0          0          0
# 439         0         0         0          0          0          0          0
# 440         0         0         0          0          0          0          0
# 441         0         0         0          0          0          0          0
#
#      3/14/2020
# 0           82
# 1          773
# 2          212
# 3            1
# 4          238
# ..         ...
# 437          1
# 438          1
# 439          1
# 440          1
# 441          0
#
# [442 rows x 53 columns]

# %%
df = df_infect[df_infect.columns[4:]] - (df_deaths[df_deaths.columns[4:]] + df_revocer[df_revocer.columns[4:]])

# %%
df
# Out:
#      1/22/2020  1/23/2020  1/24/2020  1/25/2020  1/26/2020  1/27/2020  \
# 0            2          3          5          7          6          6
# 1            2          1          2          2          3          3
# 2            0          1          3          3          4          5
# 3            0          0          0          1          1          1
# 4            0          0          0          3          4          4
# ..         ...        ...        ...        ...        ...        ...
# 437          0          0          0          0          0          0
# 438          0          0          0          0          0          0
# 439          0          0          0          0          0          0
# 440          0          0          0          0          0          0
# 441          0          0          0          0          0          0
#
#      1/28/2020  1/29/2020  1/30/2020  1/31/2020  ...  3/5/2020  3/6/2020  \
# 0            9          9          9         14  ...        15        16
# 1            6          6         10         14  ...       311       368
# 2            7          7         10         13  ...        39        52
# 3            1          1          1          1  ...         0         0
# 4            4          7          8          8  ...        28        61
# ..         ...        ...        ...        ...  ...       ...       ...
# 437          0          0          0          0  ...         0         0
# 438          0          0          0          0  ...         0         0
# 439          0          0          0          0  ...         0         0
# 440          0          0          0          0  ...         0         0
# 441          0          0          0          0  ...         0         0
#
#      3/7/2020  3/8/2020  3/9/2020  3/10/2020  3/11/2020  3/12/2020  3/13/2020  \
# 0          18        18        18         19         24         35         39
# 1         379       420       425        470        506        505        564
# 2          60        72        72         82         82         82        103
# 3           0         0         0          0          0          0          0
# 4          70        75        93        105        123        123        171
# ..        ...       ...       ...        ...        ...        ...        ...
# 437         0         0         0          0          0          0          0
# 438         0         0         0          0          0          0          0
# 439         0         0         0          0          0          0          0
# 440         0         0         0          0          0          0          0
# 441         0         0         0          0          0          0          0
#
#      3/14/2020
# 0           46
# 1          633
# 2          107
# 3            0
# 4          203
# ..         ...
# 437          1
# 438          1
# 439          1
# 440          1
# 441          0
#
# [442 rows x 53 columns]

# %%
df_infect[df_infect.columns[4:]] = df

# %%
#df_infect.to_csv('Currently_infected.tsv',sep='\t', quoting=csv.QUOTE_NONE)

# %%
np_infect = np.array(df_infect)
countries = np.unique(np_infect[:,1])

# %%
dict_c ={country:[0]*len(list(df_deaths[1:1])[4:]) for country in countries} 
for i,row in enumerate(np_infect):
    country = row[1]
    for i,val in enumerate(row[4:]):
        dict_c[country][i]+= val

# %%
df_fin = pd.DataFrame.from_dict(dict_c, orient='index')

# %%
df_fin.to_csv('Currently_infected_cumu.csv',sep='\t')
